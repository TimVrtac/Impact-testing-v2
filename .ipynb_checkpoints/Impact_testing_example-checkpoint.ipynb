# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt

# %%
from ImpTesting import ImpactTesting

# %% [markdown]
# ### Measurement

# %%
sensor_list = ['45250', 'LW312598', 'LW168022', '177269', '1669', 'LW184270', '4010', '4009', 'LW191475']

# %%
imp_testing = ImpactTesting(task_name='Extra_dummies_task',
                            sensor_xlsx='Merilna oprema.xlsx', sensor_list=sensor_list,
                           sampling_rate=51200, samps_per_chn=51200,
                           acquisition_time=1, no_impacts=10, trigger_level=5)

# %%
plt.figure(figsize=(15,5))
plt.plot(imp_testing.measurement_array[1,1,0:500])
plt.grid()

# %%
imp_testing.start_measurement(save_to='../meritve/ref_cela_extra_d/1')
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 imp_testing.start_measurement(save_to='../meritve/ref_cela_extra_d/1')
#
# File ~\OneDrive - Univerza v Ljubljani\Documents\Doktorat\Projekt_1\Faza V - nova struktura\Eksperiment\Impact testing v2\ImpTesting.py:195, in ImpactTesting.start_measurement(self, save_to)
#     193 winsound.Beep(410, 180)
#     194 # Meritev
# --> 195 self.measurement_array[imp, :, :] = self.acquire_signal()
#     196 # Check for chn overload
#     197 no_overload = self.check_chn_overload(imp)
#
# File ~\OneDrive - Univerza v Ljubljani\Documents\Doktorat\Projekt_1\Faza V - nova struktura\Eksperiment\Impact testing v2\ImpTesting.py:372, in ImpactTesting.acquire_signal(self)
#     370 trig = True
#     371 while True:
# --> 372     data = self.measure()
#     373     trigger.add_data(data.T)
#     374     if trigger.finished:
#
# File ~\OneDrive - Univerza v Ljubljani\Documents\Doktorat\Projekt_1\Faza V - nova struktura\Eksperiment\Impact testing v2\ImpTesting.py:384, in ImpactTesting.measure(self)
#     382 # *2, da zagotovo zajamemo dovolj podatkov. Trigger gledamo samo prvo polovico časa.
#     383 self.task.start()
# --> 384 data = np.array(self.task.read(number_of_samples_per_channel=no_smpl_per_chn, timeout=10.0))
#     385 #self.task.wait_until_done(timeout=10)
#     386 self.task.stop()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\nidaqmx\task.py:668, in Task.read(self, number_of_samples_per_channel, timeout)
#     666     else:
#     667         data = numpy.zeros(array_shape, dtype=numpy.float64)
# --> 668         samples_read = _read_analog_f_64(
#     669             self._handle, data, number_of_samples_per_channel, timeout)
#     671 # Digital Input or Digital Output
#     672 elif (read_chan_type == ChannelType.DIGITAL_INPUT or
#     673         read_chan_type == ChannelType.DIGITAL_OUTPUT):
#
# File C:\ProgramData\Anaconda3\lib\site-packages\nidaqmx\_task_modules\read_functions.py:27, in _read_analog_f_64(task_handle, read_array, num_samps_per_chan, timeout, fill_mode)
#      19         if cfunc.argtypes is None:
#      20             cfunc.argtypes = [
#      21                 lib_importer.task_handle, ctypes.c_int, ctypes.c_double,
#      22                 c_bool32,
#      23                 wrapped_ndpointer(dtype=numpy.float64, flags=('C', 'W')),
#      24                 ctypes.c_uint, ctypes.POINTER(ctypes.c_int),
#      25                 ctypes.POINTER(c_bool32)]
# ---> 27 error_code = cfunc(
#      28     task_handle, num_samps_per_chan, timeout, fill_mode.value,
#      29     read_array, read_array.size,
#      30     ctypes.byref(samps_per_chan_read), None)
#      31 check_for_error(error_code, samps_per_chan_read=samps_per_chan_read.value)
#      33 return samps_per_chan_read.value
#
# KeyboardInterrupt:

# %%
# closes the task
imp_testing.close_task()

# %% [markdown]
# ### ImpactTesting class attributes

# %%
imp_testing.device_list
# Out:
# ['cDAQ6', 'cDAQ6Mod1', 'SimDev1']

# %%
imp_testing.all_channels
# Out:
# ['0x', '0y', '0z', 'force']

# %%
imp_testing.device_list
# Out:
# ['cDAQ6', 'cDAQ6Mod1', 'SimDev1']

# %%
imp_testing.force_chn_ind
# Out:
# 3

# %%
imp_testing.close_task()

# %%
results = imp_testing.measurement_array
results.shape
# Out:
# (3, 4, 25600)
