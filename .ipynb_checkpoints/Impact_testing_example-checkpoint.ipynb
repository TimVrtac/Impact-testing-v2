# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt

# %%
from ImpTesting import ImpactTesting

# %% [markdown]
# ### Measurement

# %%
# List of sensor serial numbers
sensor_list = ['45250', 'LW312598', 'LW168022', '177269', '1669', 'LW184270', '4010', '4009', 'LW191475']

# %%
# Impact testing instance
imp_testing = ImpactTesting(task_name='My_task',
                            sensor_xlsx='Merilna oprema.xlsx', sensor_list=sensor_list,
                           sampling_rate=51200, samps_per_chn=51200,
                           acquisition_time=1, no_impacts=3, trigger_level=5)

# %%
imp_testing.start_measurement(save_to='file_name') # save_to arument is optional (file name can be chosen later)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# GridspecLayout(children=(SelectMultiple(index=(0, 1, 2), layout=Layout(grid_area='widget001', width='200px'), …
# Output()

# %%
# closes the task
imp_testing.close_task()

# %% [markdown]
# ### ImpactTesting class attributes

# %%
# List of connected devices
print(imp_testing.device_list)
# Out:
# ['cDAQ5', 'cDAQ5Mod1', 'cDAQ5Mod2', 'cDAQ5Mod3', 'cDAQ5Mod4', 'cDAQ5Mod5', 'cDAQ5Mod6', 'cDAQ5Mod7', 'cDAQ5Mod8', 'SimDev1']

# %%
# All channels in the task
print(imp_testing.all_channels)
# Out:
# ['force', '1x', '1y', '1z', '2x', '2y', '2z', '3x', '3y', '3z', '4x', '4y', '4z', '5x', '5y', '5z', '6x', '6y', '6z', '7x', '7y', '7z', '8x', '8y', '8z']

# %%
# Force channel index
imp_testing.force_chn_ind
# Out:
# 0

# %%
# Measurement results - shape: (measurements, channels, samples)
results = imp_testing.measurement_array
results.shape
# Out:
# (3, 25, 51200)

# %%
# measurement information
print(imp_testing.meas_info)
# Out:
# {'Sampling rate': 51200, 'Acquisiton time': 1, 'Used devices': ['cDAQ5', 'cDAQ5Mod1', 'cDAQ5Mod2', 'cDAQ5Mod3', 'cDAQ5Mod4', 'cDAQ5Mod5', 'cDAQ5Mod6', 'cDAQ5Mod7', 'cDAQ5Mod8', 'SimDev1'], 'Channels': ['force', '1x', '1y', '1z', '2x', '2y', '2z', '3x', '3y', '3z', '4x', '4y', '4z', '5x', '5y', '5z', '6x', '6y', '6z', '7x', '7y', '7z', '8x', '8y', '8z'], 'Force channel index': 0}
