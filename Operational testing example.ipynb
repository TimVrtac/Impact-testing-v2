# %%
# %load_ext autoreload
# %autoreload 2

# %%
from VibTesting import VibTesting

# %% [markdown]
# # Measurement

# %%
# List of sensor serial numbers
sensor_list = ['4010']

# %%
# Vibrational testing class instance
op_testing = VibTesting(task_name='My_task',
                            sensor_xlsx='Merilna oprema.xlsx', sensor_list=sensor_list,
                           sampling_rate=51200, samps_per_chn=51200,
                           acquisition_time=1, trigger_level=5)
# Out:
# No force sensor.

# %%
op_testing.start_op_measurement(acq_time=5, start_w_button=True)
# Out:
# Start btn pressed
#   0%|          | 0/5 [00:00<?, ?it/s]
# GridspecLayout(children=(Button(description='Save', layout=Layout(grid_area='widget001'), style=ButtonStyle())…
# Output()

# %%
# close the task
imp_testing.close_task()
